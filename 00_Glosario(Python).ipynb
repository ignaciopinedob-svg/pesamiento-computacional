# %% [markdown]
# <a href="https://colab.research.google.com/github/ignaciopinedob-svg/pesamiento-computacional/blob/main/00_Glosario(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Glosario**
#
# 1. Division entera (` // `):
# Division entre n°enteros en donde el resultado es siempre entero, por lo tanto, se redondea al entero menor.
#
# ---
# 2. Expresión:
# Coleccion de operadores y números
#
# ---
# 3. Valor:
# Es el resultado de una expresión
#
# ---
# 4. Error: SyntaxError:
# Cuando llamo una funcion y cometo un error en su escritura (abs 42, es un error pues no puse los parentesis en el 42)
#
# ---
# 5. Función `Len`:
# Cuenta la cantidad de caracteres que tiene un string, Si no pongo parentesis tengo error de sintaxis
#
# ---
# 6. Error de tipo (Type Error):
# Cuando se ejecuta una operacion que no esta asociada a un tipo. Ejemplo, dividir un string, pues son string y no se pueden dividir
#
# ---
# 7. Debugging:
